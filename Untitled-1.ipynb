# %%
import sys
print(sys.executable)
import redback
print(redback.__version__)
# Out:
# /opt/miniconda3/envs/redback/bin/python
# 1.0.2

# %%
import redback
print(redback.__version__)
# Out:
# No module named 'lalsimulation'
# lalsimulation is not installed. Some EOS based models will not work. Please use bilby eos or pass your own EOS generation class to the model
# 11:10 bilby INFO    : Running bilby version: 2.3.0
# 11:10 redback INFO    : Running redback version: 1.0.2
# 1.0.2

# %%
import numpy as np
import pandas as pd
from redback.transient_models.phenomenological_models import exponential_powerlaw, fallback_lbol
from redback.transient_models.magnetar_models import magnetar_only, basic_magnetar
from redback.transient_models.magnetar_driven_ejecta_models import _ejecta_dynamics_and_interaction
from redback.transient_models.shock_powered_models import  _shocked_cocoon, _csm_shock_breakout
import redback.interaction_processes as ip
import redback.sed as sed
from redback.sed import flux_density_to_spectrum, blackbody_to_spectrum
import redback.photosphere as photosphere
from astropy.cosmology import Planck18 as cosmo  # noqa
from redback.utils import (calc_kcorrected_properties, citation_wrapper, logger, get_csm_properties, nu_to_lambda,
                           lambda_to_nu, velocity_from_lorentz_factor, build_spectral_feature_list)
from redback.constants import day_to_s, solar_mass, km_cgs, au_cgs, speed_of_light, sigma_sb
from inspect import isfunction
import astropy.units as uu
from collections import namedtuple
from scipy.interpolate import interp1d, RegularGridInterpolator
# Out:
# No module named 'lalsimulation'
# lalsimulation is not installed. Some EOS based models will not work. Please use bilby eos or pass your own EOS generation class to the model
# 11:06 bilby INFO    : Running bilby version: 2.3.0
# 11:06 redback INFO    : Running redback version: 1.0.2
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from redback.transient_models.phenomenological_models import exponential_powerlaw, fallback_lbol
#       4 from redback.transient_models.magnetar_models import magnetar_only, basic_magnetar
#       5 from redback.transient_models.magnetar_driven_ejecta_models import _ejecta_dynamics_and_interaction
#
# ImportError: cannot import name 'fallback_lbol' from 'redback.transient_models.phenomenological_models' (/opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/transient_models/phenomenological_models.py)

# %%
#I DID IT FINALLY !! THIA IS MY CLONED REPO FROM GITHUB
#NOW I HAVE TO GET REDBACK IN HERE AND RUN SOME CODE 

mag = sn1998bw_template(tts,redshift=1, amplitude=0.001, output_format='magnitude', bands='bessellb')
plt.plot(tts, mag)
plt.gca().invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #I DID IT FINALLY !! THIA IS MY CLONED REPO FROM GITHUB
#       2 #NOW I HAVE TO GET REDBACK IN HERE AND RUN SOME CODE
# ----> 4 mag = sn1998bw_template(tts,redshift=1, amplitude=0.001, output_format='magnitude', bands='bessellb')
#       5 plt.plot(tts, mag)
#       6 plt.gca().invert_yaxis()
#
# NameError: name 'sn1998bw_template' is not defined
