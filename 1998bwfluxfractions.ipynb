# %%
import redback
print(redback.__file__)
# Out:
# No module named 'lalsimulation'
# lalsimulation is not installed. Some EOS based models will not work. Please use bilby eos or pass your own EOS generation class to the model
# 16:34 bilby INFO    : Running bilby version: 2.3.0
# 16:34 redback INFO    : Running redback version: 1.12.1
# /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/__init__.py

# %%
import redback

# %%
''' something about my virtual environment is wrong - not all the redback packages have downloaded 
- it was all working fine a day ago but now not so much !! oh well . 
I will try and come basck to and fix when i know exactly what gavin wants me to do. '''
# Out:
# ' something about my virtual environment is wrong - not all the redback packages have downloaded \n- it was all working fine a day ago but now not so much !! oh well . \nI will try and come basck to and fix when i know exactly what gavin wants me to do. '

# %%
import sys
print(sys.executable)
# Out:
# /opt/miniconda3/envs/redback/bin/python

# %%
import redback
print(redback.__version__)
# Out:
# 1.12.1

# %%
import numpy as np
import pandas as pd
from redback.transient_models.phenomenological_models import exponential_powerlaw, fallback_lbol
from redback.transient_models.magnetar_models import magnetar_only, basic_magnetar
from redback.transient_models.magnetar_driven_ejecta_models import _ejecta_dynamics_and_interaction
from redback.transient_models.shock_powered_models import  _shocked_cocoon, _csm_shock_breakout
import redback.interaction_processes as ip
import redback.sed as sed
#from redback.sed import flux_density_to_spectrum, blackbody_to_spectrum
import redback.photosphere as photosphere
from astropy.cosmology import Planck18 as cosmo  # noqa
#from redback.utils import (calc_kcorrected_properties, citation_wrapper, logger, get_csm_properties, nu_to_lambda,
                          # lambda_to_nu, velocity_from_lorentz_factor, build_spectral_feature_list)
from redback.constants import day_to_s, solar_mass, km_cgs, au_cgs, speed_of_light, sigma_sb
from inspect import isfunction
import astropy.units as uu
import astropy.constants as cc
from collections import namedtuple
from scipy.interpolate import interp1d, RegularGridInterpolator

import matplotlib.pyplot as plt

# %%
#I DID IT FINALLY !! THIA IS MY CLONED REPO FROM GITHUB
#NOW I HAVE TO GET REDBACK IN HERE AND RUN SOME CODE 

#define variables 
#rename tts as time
time = np.geomspace(0.01, 90, 200) 

#amplitude and redshift are defined at the end for plotting 

def sn1998bw_template(time, redshift, amplitude, **kwargs):
    """
    A wrapper to the SN1998bw template. Only valid between 1100-11000 Angstrom and 0.01 to 90 days post explosion in rest frame

    Parameters
    ----------
    time
        time in days in observer frame (post explosion)
    redshift
        redshift
    amplitude
        amplitude scaling factor, where 1.0 is the original brightness of SN1998bw; and f_lambda is scaled by this factor
    kwargs
        Additional keyword arguments required by redback.
    frequency
        Required if output_format is 'flux_density'. frequency to calculate - Must be same length as time array or a single number).
    bands
        Required if output_format is 'magnitude' or 'flux'.
    output_format
        'flux_density', 'magnitude', 'spectra', 'flux', 'sncosmo_source'
    cosmology
        Cosmology to use for luminosity distance calculation. Defaults to Planck18. Must be a astropy.cosmology object.
    Returns
    -------
        set by output format - 'flux_density', 'magnitude', 'spectra', 'flux', 'sncosmo_source'

    """
    import sncosmo
    model = sncosmo.Model(source='v19-1998bw')
    original_redshift = 0.0085
    cosmology = kwargs.get("cosmology", cosmo)
    original_dl = (43*uu.Mpc).to(uu.cm).value

    # From roughly matching to Galama+ or Clocchiatti+1998bw light curves
    original_peak_time = 15
    model.set(z=original_redshift, t0=original_peak_time)
    model.set_source_peakmag(14.25, band='bessellb', magsys='ab')
    lls = np.linspace(1620, 11000, 300)
    f_lambda = model.flux(time, lls) #erg/s/cm^2/Angstrom.
    l_lambda = f_lambda * 4 * np.pi * original_dl**2  # erg/s/Angstrom

    # We consider this the rest frame spectrum of 1998bw. Now we can redshift it and scale it.
    time_obs = time * (1 + redshift)
    lambda_obs = lls * (1 + redshift)
    dl_new = cosmology.luminosity_distance(redshift).cgs.value
    f_lambda_obs = l_lambda / (4 * np.pi * dl_new**2)
    f_lambda_obs = amplitude * f_lambda_obs * (1 + redshift) # accounting for bandwidth stretching
    f_lambda_obs = f_lambda_obs * uu.erg / uu.s / uu.cm ** 2 / uu.Angstrom
    if kwargs['output_format'] == 'flux_density':
        frequency = kwargs['frequency']
        # work in obs frame
        ff_array = lambda_to_nu(lambda_obs)

        # Convert flux density to mJy
        fmjy = f_lambda_obs.to(uu.mJy, equivalencies=uu.spectral_density(wav=lambda_obs * uu.Angstrom)).value
        # Create interpolator on obs frame grid
        flux_interpolator = RegularGridInterpolator(
            (time_obs, ff_array),
            fmjy,
            bounds_error=False,
            fill_value=0.0)

        # Prepare points for interpolation
        if isinstance(frequency, (int, float)):
            frequency = np.ones_like(time) * frequency

        # Create points for evaluation
        points = np.column_stack((time, frequency))

        # Return interpolated flux density with (1+z) correction for observer frame
        return flux_interpolator(points)
    elif kwargs['output_format'] == 'spectra':
        return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
                                                                    lambdas=lambda_obs,
                                                                    spectra=f_lambda_obs)
    else:
        return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
                                                          spectra=f_lambda_obs, lambda_array=lambda_obs,
                                                          **kwargs)
    
mag = sn1998bw_template(time, redshift=1, amplitude=0.001, output_format='magnitude', bands='bessellb')
plt.plot(time, mag)
plt.xlabel("Time")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis() #lower magnitudes = brighter
plt.show()

#why is y axis so large ??
#for extinction can add extinction_corrected = True - is this a thing in redback ?

# %%
#now do this but for flux density
#cant use single values for frquencies !! have to do it over different ones !! 
#sample over the filter bandpass using sncosmo 

#model answer for band integration for flux density - not using sn1998bw template anymore ? 
import sncosmo

def sn1998bw_flux_density(time, redshift, amplitude, band='bessellv'):
    model = sncosmo.Model(source='v19-1998bw')
    model.set(z=redshift)
    model.set_source_peakmag(14.25, band='bessellb', magsys='ab')
    # amplitude scaling if needed
    flux = model.bandflux(band, time, zp=0, zpsys='ab') * amplitude
    return flux

#have to change this band each time to match the GRB observations !! 
#e.g. r band = bessellr 
#fitzpatrick corrects flux density at the wavelength i give it -- cant work across bands 
flux = sn1998bw_flux_density(time, redshift=1, amplitude=0.001, band='bessellv')
plt.plot(time, flux)
plt.xlabel("Time")
plt.ylabel("Flux Density")
plt.show()

#correct? sanity check tomorrow- this is the best  got but still need to fully understand

# %%
#USEFUL CONVERSION ? 
def calc_ABmag_from_flux_density(fluxdensity):
    """
    Calculate AB magnitude from flux density assuming monochromatic AB filter

    :param fluxdensity: Flux density values in mJy
    :return: AB magnitude
    """
    return (fluxdensity * uu.mJy).to(uu.ABmag)

# %%
#now do this but for flux density
#cant use single values for frquencies !! have to do it over different ones !! 
#sample over the filter bandpass using sncosmo 

time = np.geomspace(0.01, 90, 200) 

#for flux density i have to use frequency of the filter STATED AS REQUIRED IN REDBACK DOCUMENTATION !effective width = same order of mag so ok to use? check with gavin ? 
#how to import the filters information from redback entirely ? 
v_band_frequency = 8.58703e+13 #Hz 

v_wavelength = 	5477.70000 #angstroms 

#lambda_array = np.array([5477.70000])

#this converts angstrom wavelength back to metres then divides m/s by m 
#alternatively, keep wavelength in m and then change c to be angstrom/s

import astropy.constants as cc
#not working for some reason - just use the normal c value
#need to import in the actual definition? 
c = 3.0e8 #m/s

def lambda_to_nu(v_wavelength):
    """
    :param wavelength: wavelength in Angstrom
    :return: frequency in Hertz
    """
    return c / (v_wavelength* 1.e-10)
    #return speed_of_light_si / (v_wavelength* 1.e-10)

#try other def
# def lambda_to_nu(lambda_array):
#     # lambda_array in Angstroms
#     c = 2.99792458e18  # speed of light in Angstrom/s
#     return c / lambda_array

def sn1998bw_template(time, redshift, amplitude, **kwargs):
    
    import sncosmo
    model = sncosmo.Model(source='v19-1998bw')
    original_redshift = 0.0085
    cosmology = kwargs.get("cosmology", cosmo)
    original_dl = (43*uu.Mpc).to(uu.cm).value

    # From roughly matching to Galama+ or Clocchiatti+1998bw light curves
    original_peak_time = 15
    model.set(z=original_redshift, t0=original_peak_time)
    model.set_source_peakmag(14.25, band='bessellb', magsys='ab')
    lls = np.linspace(1620, 11000, 300)
    f_lambda = model.flux(time, lls) #erg/s/cm^2/Angstrom.
    l_lambda = f_lambda * 4 * np.pi * original_dl**2  # erg/s/Angstrom

    # We consider this the rest frame spectrum of 1998bw. Now we can redshift it and scale it.
    time_obs = time * (1 + redshift)
    lambda_obs = lls * (1 + redshift)
    dl_new = cosmology.luminosity_distance(redshift).cgs.value
    f_lambda_obs = l_lambda / (4 * np.pi * dl_new**2)
    f_lambda_obs = amplitude * f_lambda_obs * (1 + redshift) # accounting for bandwidth stretching
    f_lambda_obs = f_lambda_obs * uu.erg / uu.s / uu.cm ** 2 / uu.Angstrom
    if kwargs['output_format'] == 'flux_density':
        frequency = kwargs['frequency']
        # work in obs frame
        ff_array = lambda_to_nu(lambda_obs)

        # Convert flux density to mJy
        fmjy = f_lambda_obs.to(uu.mJy, equivalencies=uu.spectral_density(wav=lambda_obs * uu.Angstrom)).value
        # Create interpolator on obs frame grid
        flux_interpolator = RegularGridInterpolator(
            (time_obs, ff_array),
            fmjy,
            bounds_error=False,
            fill_value=0.0)

        # Prepare points for interpolation
        if isinstance(frequency, (int, float)):
            frequency = np.ones_like(time) * frequency

        # Create points for evaluation
        points = np.column_stack((time, frequency))

        # Return interpolated flux density with (1+z) correction for observer frame
        return flux_interpolator(points)
    elif kwargs['output_format'] == 'spectra':
        return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
                                                                    lambdas=lambda_obs,
                                                                    spectra=f_lambda_obs)
    else:
        return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
                                                          spectra=f_lambda_obs, lambda_array=lambda_obs,
                                                          **kwargs)
    
#should i be changing my amplitude to be 1.0 since this is the original brightness of 1998bw ?? !! 
flux = sn1998bw_template(time, redshift=1, amplitude=0.001, output_format='flux_density', bands='bessellb', frequency = v_band_frequency)
plt.plot(time, flux)
plt.xlabel("Time")
plt.ylabel("Flux Density")
#plt.gca().invert_yaxis() #dont invert !!
plt.show()

#fix: lambda_to_nu must be defined - this is what gavin was taking about when referring to the speed of light 
#try speed of light in angstrom /s ? 
'''
def lambda_to_nu(lambda_array):
    # lambda_array in Angstroms
    c = 2.99792458e18  # speed of light in Angstrom/s
    return c / lambda_array
'''
#this keeps wavelength in angstroms and divides angstrom/s / angstrom 

#this is how it is done in redback documentation - same way ? 
#YES - but here wavelength is not an array it is a single value - perferable ? 
#MUST ENSURE WAVELENGTH IS IN TERMS OF ANGSTROMS 
#USE THE REDBACK WAY NOT THE AI WAY TO SEE IF WAVELENGTH CAN BE A SCALAR NOT ARRAY 
'''
def lambda_to_nu(wavelength):
    """
    :param wavelength: wavelength in Angstrom
    :return: frequency in Hertz
    """
    return speed_of_light_si / (wavelength * 1.e-10)
'''
#this converts angstrom wavelength back to metres then divides m/s by m 

# import astropy.constants as cc for speed_of_light_si - does this need to be in angstroms or metres ?
# Out:
# '\ndef lambda_to_nu(wavelength):\n    """\n    :param wavelength: wavelength in Angstrom\n    :return: frequency in Hertz\n    """\n    return speed_of_light_si / (wavelength * 1.e-10)\n'

# %%
#now compare to data from files and plot against the redback output 

sn1998bw_z_0_8 = pd.read_csv('/Users/helenagrabham/Downloads/98_bw_models/98bw_z0.8.txt')

sn1998bw_z_0_8.to_csv('/Users/helenagrabham/Downloads/98_bw_models/98bw_z0.8.csv', index = False)

print(sn1998bw_z_0_8)

#compare this data to the model to ensure model is behaving correctly 
#OR ! imputting the data into this model 

#choose r-band as comparison 
#compare two lots of data files from around z = 0.8 and see how they match with the redback model

time = sn1998bw_z_0_8['day']
mag_r = sn1998bw_z_0_8['r']

plt.plot(time, mag_r, '-', label = 'Observed r-band data')
plt.xlabel("Time")
plt.ylabel("Magnitude")
plt.gca().invert_yaxis() #lower magnitudes = brighter
plt.show()
# Out:
#      day       r       i       K   F070W   F115W   F150W   F277W   F356W  \
# 0    0.0  44.990  44.731  45.244  44.814  44.673  44.832  45.590  46.008
# 1    0.5  31.512  31.249  31.754  31.334  31.186  31.343  32.098  32.516
# 2    1.0  30.032  29.765  30.259  29.851  29.696  29.851  30.603  31.020
# 3    1.5  29.175  28.904  29.389  28.991  28.830  28.982  29.731  30.147
# 4    2.0  28.573  28.299  28.773  28.387  28.219  28.369  29.115  29.530
# ..   ...     ...     ...     ...     ...     ...     ...     ...     ...
# 76  38.0  24.664  24.262  24.383  24.390  23.984  24.054  24.693  25.082
# 77  38.5  24.675  24.273  24.393  24.400  23.995  24.065  24.704  25.092
# 78  39.0  24.686  24.283  24.404  24.411  24.005  24.076  24.714  25.103
# 79  39.5  24.696  24.294  24.415  24.422  24.016  24.086  24.725  25.114
# 80  40.0  24.708  24.306  24.426  24.433  24.028  24.098  24.737  25.125
#
#      F444W
# 0   46.368
# 1   32.875
# 2   31.379
# 3   30.506
# 4   29.888
# ..     ...
# 76  25.424
# 77  25.435
# 78  25.445
# 79  25.456
# 80  25.467
#
# [81 rows x 10 columns]

# %%
#now plot multiple on the same lightcurve plot 
#redshifts need to be the same here !! decrease / increase amplitude 

# Load data
data = pd.read_csv('/Users/helenagrabham/Downloads/98_bw_models/98bw_z1.0.txt', comment='#')
time = data['day']
mag_r = data['r']

mag_i = data['i']

# Model output for all bands ? what does bessellb mean B BAND !! found in tables/filters.csv 
# mag_model = sn1998bw_template(
#     time,
#     redshift=0.8,
#     amplitude=1.0,  # adjust as needed
#     output_format='magnitude',
#     bands='bessellb' #change this ? 
# )

mag_model = sn1998bw_template(
    time,
    redshift=1.0,
    amplitude=1.2,  # adjust as needed (if model too faint increase amplitude and vice versa)
    output_format='magnitude',
    bands='bessellb' #change this ? 
)
# Plot
plt.plot(time, mag_r, '-', label='Observed r-band')
plt.plot(time, mag_i, '-', label='Observed i-band')
plt.plot(time, mag_model, '-', label='Model r-band')
plt.gca().invert_yaxis()
plt.xlabel('Time (days)')
plt.ylabel('Magnitude')
plt.legend()
plt.show()

#is this extinction corrected in redback ? need to add it in ! simply done in redback apparently ? 

#working with apparent magnitudes

# %%
#this plot gives us the best model params we need to compare SN 1998bw model to other events ? YES but must be same redshift obs - model
#to make more comparable change the amplitude param 
#also have to apply extinction - HOW 
#just apply extinction correction to model ? apply host galaxy extinction - is data already extinction corrected? ask gavin 

#sometimes amplitude is artificially low because model thinks SN is naturally dim when really it is hidden behind dust 

'''attempt a calculation without the extinction correction and then if doesnt work see where to go from gavin'''
# Out:
# 'attempt a calculation without the extinction correction and then if doesnt work see where to go from gavin'

# %%
#NEW: attempt to get the observed magnitude of 1998bw from its model using specific epoch, redshift and filter 
#take data for observed mag of a GRB event at specific redshift and epoch in a given band, find what the observed magnitude of 1998bw was for the same redshift, epoch, band
#calculate a ratio of the two 

epoch = 11.0
z_event = 0.0331
band = 'bessellr'  # Replace with your desired filter

#observed known value of magnutde of GRB event
#eventually make this into a list so that I can easily work out for all - if this calc is correct !! 

#060218 SN 2006aj apparent magnitude = 17.22 in the r-band MUST BE ASSOCIATED WITH A SPECIFIC EPOCH 11 days 
m_grb = 17.22

# Get SN 1998bw model magnitude at the specified epoch, redshift, and filter
#is the issue the band or the time ? 
#time = np.array([epoch])
m_98bw = sn1998bw_template(
    time=np.array([epoch]),
    redshift=z_event, 
    amplitude=1.0, 
    output_format='magnitude', 
    bands=band
)


print("DEBUG: m_98bw =", m_98bw, "type:", type(m_98bw))


# Extract the magnitude value if output is an array
# m_98bw_val = m_98bw[0] if isinstance(m_98bw, (list, np.ndarray)) else m_98bw

# print(f"SN 1998bw model magnitude at {epoch} days, z={z_event}, band={band}: {m_98bw_val}")

# #now calculate the final ratio
# mag_diff = m_grb - m_98bw_val
# mag_ratio = 10**(-0.4 * mag_diff)

# print(f"At {epoch} days, the GRB is {mag_ratio:.2f} x as bright as SN 1998bw.")

#WHERE IS EPOCH = 11.0 days being used now ????
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 18
#      13 m_grb = 17.22
#      15 # Get SN 1998bw model magnitude at the specified epoch, redshift, and filter
#      16 #is the issue the band or the time ?
#      17 #time = np.array([epoch])
# ---> 18 m_98bw = sn1998bw_template(
#      19     time=np.array([epoch]),
#      20     redshift=z_event,
#      21     amplitude=1.0,
#      22     output_format='magnitude',
#      23     bands=band
#      24 )
#      27 print("DEBUG: m_98bw =", m_98bw, "type:", type(m_98bw))
#      30 # Extract the magnitude value if output is an array
#      31 # m_98bw_val = m_98bw[0] if isinstance(m_98bw, (list, np.ndarray)) else m_98bw
#      32
#    (...)
#      40
#      41 #WHERE IS EPOCH = 11.0 days being used now ????
#
# Cell In[7], line 86, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      82     return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
#      83                                                                 lambdas=lambda_obs,
#      84                                                                 spectra=f_lambda_obs)
#      85 else:
# ---> 86     return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
#      87                                                       spectra=f_lambda_obs, lambda_array=lambda_obs,
#      88                                                       **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:686, in get_correct_output_format_from_spectra(time, time_eval, spectra, lambda_array, **kwargs)
#     684 # clean up spectrum to remove nonsensical values before creating sncosmo source
#     685 spectra = np.nan_to_num(spectra)
# --> 686 spectra[spectra.value == np.nan_to_num(np.inf)] = 1e-30 * np.mean(spectra[5])
#     687 spectra[spectra.value == 0.] = 1e-30 * np.mean(spectra[5])
#     688 time_spline_degree = kwargs.get('time_spline_degree', 3)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/astropy/units/quantity.py:1265, in Quantity.__getitem__(self, key)
#    1260     return self._new_view(
#    1261         self.view(np.ndarray)[key], self.unit[key], propagate_info=False
#    1262     )
#    1264 try:
# -> 1265     out = super().__getitem__(key)
#    1266 except IndexError:
#    1267     # We want zero-dimensional Quantity objects to behave like scalars,
#    1268     # so they should raise a TypeError rather than an IndexError.
#    1269     if self.isscalar:
#
# IndexError: index 5 is out of bounds for axis 0 with size 1

# %%
#NEW: ty to use interpolation 
import numpy as np

# 1. Generate time array
times = np.geomspace(0.01, 90, 200)

z_event = 0.0331

band = 'bessellr'
# 2. Compute magnitudes for all times
mags = sn1998bw_template(times, redshift=z_event,
    amplitude=1.0, 
    output_format='magnitude', 
    bands=band)

# 3. Interpolate to find magnitude at the desired epoch
#np.interp estimates the value of y at a given x positon 
#useful and what we need ? 
epoch = 11.0
mag_at_epoch = np.interp(epoch, times, mags)

print(f"Observed magnitude of 1998bw at {epoch} days: {mag_at_epoch:.2f}")

#now calculate the final ratio

m_grb = 17.22 
mag_diff = m_grb - mag_at_epoch
mag_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days, the GRB is {mag_ratio:.2f} x as bright as SN 1998bw.")

#the true answer is 0.7 so this is slightly overpredicting - direct method is better if i can get it to work !! 
# BUT !! take into account the k-correction and extinction of MW !! 

#was this value of observed mag already extinction corrected? where did it come from ?
# Out:
# Observed magnitude of 1998bw at 11.0 days: 16.95
# At 11.0 days, the GRB is 0.78 x as bright as SN 1998bw.

# %%
##NEW: an attempt to get the direct method working 
import numpy as np
from astropy.cosmology import Planck18

# 1. The actual data for SN 2006aj
epoch = np.array([11.0]) # Convert to array to be safe with interpolators
z_event = 0.0331
m_obs_2006aj = 17.22 

# 2. Call the template
# Note: I added 'cosmology' to ensure the function doesn't fail 
# when looking for the 'cosmo' variable inside its scope.
m_98bw_baseline = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='magnitude', 
    bands='sdssr',
    cosmology=Planck18 
)

# 3. Handle the output
# If the function returns a list or array, take the first element
if isinstance(m_98bw_baseline, (list, np.ndarray)):
    m_98bw_val = m_98bw_baseline[0]
else:
    m_98bw_val = m_98bw_baseline

# 4. Calculate Ratio
mag_diff = m_obs_2006aj - m_98bw_val
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch[0]} days (r-band):")
print(f"SN 1998bw Model Magnitude: {m_98bw_val:.2f}")
print(f"SN 2006aj Observed Magnitude: {m_obs_2006aj:.2f}")
print(f"Flux Ratio: {flux_ratio:.4f}")

#the issue is with the output format - change from magnitude to flux density to allow the output to be scalar
#buttt still uses an interpolator ?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 13
#       8 m_obs_2006aj = 17.22
#      10 # 2. Call the template
#      11 # Note: I added 'cosmology' to ensure the function doesn't fail
#      12 # when looking for the 'cosmo' variable inside its scope.
# ---> 13 m_98bw_baseline = sn1998bw_template(
#      14     time=epoch,
#      15     redshift=z_event,
#      16     amplitude=1.0,
#      17     output_format='magnitude',
#      18     bands='sdssr',
#      19     cosmology=Planck18
#      20 )
#      22 # 3. Handle the output
#      23 # If the function returns a list or array, take the first element
#      24 if isinstance(m_98bw_baseline, (list, np.ndarray)):
#
# Cell In[6], line 86, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      82     return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
#      83                                                                 lambdas=lambda_obs,
#      84                                                                 spectra=f_lambda_obs)
#      85 else:
# ---> 86     return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
#      87                                                       spectra=f_lambda_obs, lambda_array=lambda_obs,
#      88                                                       **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:686, in get_correct_output_format_from_spectra(time, time_eval, spectra, lambda_array, **kwargs)
#     684 # clean up spectrum to remove nonsensical values before creating sncosmo source
#     685 spectra = np.nan_to_num(spectra)
# --> 686 spectra[spectra.value == np.nan_to_num(np.inf)] = 1e-30 * np.mean(spectra[5])
#     687 spectra[spectra.value == 0.] = 1e-30 * np.mean(spectra[5])
#     688 time_spline_degree = kwargs.get('time_spline_degree', 3)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/astropy/units/quantity.py:1265, in Quantity.__getitem__(self, key)
#    1260     return self._new_view(
#    1261         self.view(np.ndarray)[key], self.unit[key], propagate_info=False
#    1262     )
#    1264 try:
# -> 1265     out = super().__getitem__(key)
#    1266 except IndexError:
#    1267     # We want zero-dimensional Quantity objects to behave like scalars,
#    1268     # so they should raise a TypeError rather than an IndexError.
#    1269     if self.isscalar:
#
# IndexError: index 5 is out of bounds for axis 0 with size 1

# %%
#NEW : redo 

import sncosmo
band = sncosmo.get_bandpass('sdssr')
wave_eff = band.wave_eff # Effective wavelength in Angstroms

import numpy as np
from astropy.cosmology import Planck18
import astropy.units as u

# 1. Setup
epoch = 11.0
z_event = 0.0331
m_obs_2006aj = 17.22 

# 2. Get Flux Density (returns value in mJy based on function code)
# Note: we must provide the frequency for the 'r' band. 
# For SDSS r-band, the effective wavelength is ~6231 Angstroms.
r_band_freq = (u.AA * 6231).to(u.Hz, equivalencies=u.spectral()).value

flux_mJy = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='flux_density', 
    frequency=r_band_freq,
    cosmology=Planck18 
)

# 3. Convert mJy to AB Magnitude
# The formula for AB mag is: -2.5 * log10(F_nu / 3631 Jy)
# Since our flux is in mJy, we divide by 3,631,000 mJy
m_98bw_val = -2.5 * np.log10(flux_mJy / 3631000)

# 4. Calculate Ratio
mag_diff = m_obs_2006aj - m_98bw_val
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days:")
print(f"Flux Density: {flux_mJy[0]:.4f} mJy")
print(f"SN 1998bw Model Magnitude: {m_98bw_val[0]:.2f}")
print(f"Flux Ratio: {flux_ratio[0]:.4f}")

#uu = astrophy units
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 21
#      16 # 2. Get Flux Density (returns value in mJy based on function code)
#      17 # Note: we must provide the frequency for the 'r' band.
#      18 # For SDSS r-band, the effective wavelength is ~6231 Angstroms.
#      19 r_band_freq = (u.AA * 6231).to(u.Hz, equivalencies=u.spectral()).value
# ---> 21 flux_mJy = sn1998bw_template(
#      22     time=epoch,
#      23     redshift=z_event,
#      24     amplitude=1.0,
#      25     output_format='flux_density',
#      26     frequency=r_band_freq,
#      27     cosmology=Planck18
#      28 )
#      30 # 3. Convert mJy to AB Magnitude
#      31 # The formula for AB mag is: -2.5 * log10(F_nu / 3631 Jy)
#      32 # Since our flux is in mJy, we divide by 3,631,000 mJy
#      33 m_98bw_val = -2.5 * np.log10(flux_mJy / 3631000)
#
# Cell In[6], line 61, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      59 frequency = kwargs['frequency']
#      60 # work in obs frame
# ---> 61 ff_array = lambda_to_nu(lambda_obs)
#      63 # Convert flux density to mJy
#      64 fmjy = f_lambda_obs.to(uu.mJy, equivalencies=uu.spectral_density(wav=lambda_obs * uu.Angstrom)).value
#
# NameError: name 'lambda_to_nu' is not defined

# %%
#NEW: redo of the redp 
import numpy as np
import astropy.units as uu  # The function uses 'uu'
from astropy.cosmology import Planck18 as cosmo # The function uses 'cosmo' as a default
import sncosmo

# 1. Setup Data
epoch = 11.0
z_event = 0.0331
m_obs_2006aj = 17.22 

# 2. Get Band Info
band = sncosmo.get_bandpass('sdssr')
# Use the exact wave_eff from the bandpass
r_band_freq = (band.wave_eff * uu.AA).to(uu.Hz, equivalencies=uu.spectral()).value

# 3. Call Template 
# We pass Planck18 explicitly to avoid 'cosmo' undefined errors
flux_mJy_array = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='flux_density', 
    frequency=r_band_freq,
    cosmology=cosmo 
)

# 4. Extract scalar and convert to Mag
# Interpolators return arrays; we take the first element [0] to get a number
flux_mJy = float(flux_mJy_array[0])

# AB Magnitude formula
m_98bw_val = -2.5 * np.log10(flux_mJy / 3631000)

# 5. Comparison
mag_diff = m_obs_2006aj - m_98bw_val
flux_ratio = 10**(-0.4 * mag_diff)

print(f"--- Results for Epoch {epoch} ---")
print(f"Flux Density: {flux_mJy:.6f} mJy")
print(f"SN 1998bw Baseline Mag: {m_98bw_val:.2f}")
print(f"SN 2006aj Observed Mag: {m_obs_2006aj:.2f}")
print(f"Flux Ratio (06aj/98bw): {flux_ratio:.4f}")

#GIVING UP .... 
#have to try interpolation and then correcting for MW extinction + maybe host too + also k-correction and then it might work
#i know what i need to do / where i need to go and can show gavin tomorrow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 19
#      15 r_band_freq = (band.wave_eff * uu.AA).to(uu.Hz, equivalencies=uu.spectral()).value
#      17 # 3. Call Template
#      18 # We pass Planck18 explicitly to avoid 'cosmo' undefined errors
# ---> 19 flux_mJy_array = sn1998bw_template(
#      20     time=epoch,
#      21     redshift=z_event,
#      22     amplitude=1.0,
#      23     output_format='flux_density',
#      24     frequency=r_band_freq,
#      25     cosmology=cosmo
#      26 )
#      28 # 4. Extract scalar and convert to Mag
#      29 # Interpolators return arrays; we take the first element [0] to get a number
#      30 flux_mJy = float(flux_mJy_array[0])
#
# Cell In[6], line 61, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      59 frequency = kwargs['frequency']
#      60 # work in obs frame
# ---> 61 ff_array = lambda_to_nu(lambda_obs)
#      63 # Convert flux density to mJy
#      64 fmjy = f_lambda_obs.to(uu.mJy, equivalencies=uu.spectral_density(wav=lambda_obs * uu.Angstrom)).value
#
# NameError: name 'lambda_to_nu' is not defined

# %%
#now compare to an event: 060218 SN 2006aj apparent magnitude = 17.22 in the r-band MUST BE ASSOCIATED WITH A SPECIFIC EPOCH 11 days 

#ive already defined it as a function - not something i can just import ? get rid of this line below and see if code now mkes more sense ? 
#from redback.transient_models.supernova_models import sn1998bw_template

# Epoch we want to compare (e.g., 20 days post-explosion)
epoch = 11.0
z_event = 0.0331 # Redshift of your new GRB

# 1. Get 1998bw magnitude at this epoch
m_98bw = sn1998bw_template(time=epoch, redshift=z_event, amplitude=1.0, 
                           output_format='magnitude', bands='bessellb')

# 2. Get your new GRB's magnitude at this epoch (from your Redback fit)
# Let's say your fit found amplitude = 0.8
m_grb = sn1998bw_template(time=epoch, redshift=z_event, amplitude=0.8, 
                          output_format='magnitude', bands='bessellb')

# 3. Calculate Ratio
mag_diff = m_grb - m_98bw
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days, the GRB is {flux_ratio:.2f}x as bright as SN 1998bw.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       8 z_event = 0.0331 # Redshift of your new GRB
#      10 # 1. Get 1998bw magnitude at this epoch
# ---> 11 m_98bw = sn1998bw_template(time=epoch, redshift=z_event, amplitude=1.0,
#      12                            output_format='magnitude', bands='bessellb')
#      14 # 2. Get your new GRB's magnitude at this epoch (from your Redback fit)
#      15 # Let's say your fit found amplitude = 0.8
#      16 m_grb = sn1998bw_template(time=epoch, redshift=z_event, amplitude=0.8,
#      17                           output_format='magnitude', bands='bessellb')
#
# Cell In[6], line 86, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      82     return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
#      83                                                                 lambdas=lambda_obs,
#      84                                                                 spectra=f_lambda_obs)
#      85 else:
# ---> 86     return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
#      87                                                       spectra=f_lambda_obs, lambda_array=lambda_obs,
#      88                                                       **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:689, in get_correct_output_format_from_spectra(time, time_eval, spectra, lambda_array, **kwargs)
#     687 spectra[spectra.value == 0.] = 1e-30 * np.mean(spectra[5])
#     688 time_spline_degree = kwargs.get('time_spline_degree', 3)
# --> 689 source = RedbackTimeSeriesSource(phase=time_eval, wave=lambda_array, flux=spectra,
#     690                                  time_spline_degree=time_spline_degree)
#     691 if kwargs['output_format'] == 'flux':
#     692     bands = kwargs['bands']
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:131, in RedbackTimeSeriesSource.__init__(self, phase, wave, flux, **kwargs)
#     120 def __init__(self, phase, wave, flux, **kwargs):
#     121     """
#     122     RedbackTimeSeriesSource is a subclass of sncosmo.TimeSeriesSource that adds the ability to return the
#     123     flux density at a given time and wavelength, and changes
#    (...)
#     129     :param kwargs: additional arguments
#     130     """
# --> 131     super(RedbackTimeSeriesSource, self).__init__(phase=phase, wave=wave, flux=flux, **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/sncosmo/models.py:530, in TimeSeriesSource.__init__(self, phase, wave, flux, zero_before, time_spline_degree, name, version)
#     528 self._wave = wave
#     529 self._parameters = np.array([1.])
# --> 530 self._model_flux = Spline2d(phase, wave, flux, kx=time_spline_degree,
#     531                             ky=3)
#     532 self._zero_before = zero_before
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/scipy/interpolate/_fitpack2.py:1590, in RectBivariateSpline.__init__(self, x, y, z, bbox, kx, ky, s)
#    1588     raise ValueError('y must be strictly increasing')
#    1589 if not x.size == z.shape[0]:
# -> 1590     raise ValueError('x dimension of z must have same number of '
#    1591                      'elements as x')
#    1592 if not y.size == z.shape[1]:
#    1593     raise ValueError('y dimension of z must have same number of '
#    1594                      'elements as y')
#
# ValueError: x dimension of z must have same number of elements as x

# %%
#i already know the apparent magnitude of the event so use it !! 
import numpy as np
# Ensure you use the custom function you defined in your previous script
# from redback.transient_models.supernova_models import sn1998bw_template

#i cant import supernova template - what is the issue here !!!! 
#this direct method is better than using interpolation !!

# 1. The actual data for SN 2006aj
epoch = 11.0
z_event = 0.0331
m_obs_2006aj = 17.22  # The r-band apparent magnitude you provided

# 2. Get the 1998bw "Standard" magnitude at THIS epoch and THIS redshift
# We use amplitude=1.0 to get the 'baseline'
m_98bw_baseline = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='magnitude', 
    bands='sdssr' # Match the r-band of your observation
)

# 3. Calculate Ratio
# mag_diff = Observed - Reference
mag_diff = m_obs_2006aj - m_98bw_baseline
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days (r-band):")
print(f"SN 1998bw Model Magnitude: {m_98bw_baseline:.2f}")
print(f"SN 2006aj Observed Magnitude: {m_obs_2006aj:.2f}")
print(f"Flux Ratio: {flux_ratio:.4f}")

#THIS WORKED !! TRY FOR ANOTHER WHICH I KNOW TO BE TRUE THEN CAN CALCULATE THE REST OF THEM
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#       9 m_obs_2006aj = 17.22  # The r-band apparent magnitude you provided
#      11 # 2. Get the 1998bw "Standard" magnitude at THIS epoch and THIS redshift
#      12 # We use amplitude=1.0 to get the 'baseline'
# ---> 13 m_98bw_baseline = sn1998bw_template(
#      14     time=epoch,
#      15     redshift=z_event,
#      16     amplitude=1.0,
#      17     output_format='magnitude',
#      18     bands='sdssr' # Match the r-band of your observation
#      19 )
#      21 # 3. Calculate Ratio
#      22 # mag_diff = Observed - Reference
#      23 mag_diff = m_obs_2006aj - m_98bw_baseline
#
# Cell In[6], line 86, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      82     return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
#      83                                                                 lambdas=lambda_obs,
#      84                                                                 spectra=f_lambda_obs)
#      85 else:
# ---> 86     return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
#      87                                                       spectra=f_lambda_obs, lambda_array=lambda_obs,
#      88                                                       **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:689, in get_correct_output_format_from_spectra(time, time_eval, spectra, lambda_array, **kwargs)
#     687 spectra[spectra.value == 0.] = 1e-30 * np.mean(spectra[5])
#     688 time_spline_degree = kwargs.get('time_spline_degree', 3)
# --> 689 source = RedbackTimeSeriesSource(phase=time_eval, wave=lambda_array, flux=spectra,
#     690                                  time_spline_degree=time_spline_degree)
#     691 if kwargs['output_format'] == 'flux':
#     692     bands = kwargs['bands']
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:131, in RedbackTimeSeriesSource.__init__(self, phase, wave, flux, **kwargs)
#     120 def __init__(self, phase, wave, flux, **kwargs):
#     121     """
#     122     RedbackTimeSeriesSource is a subclass of sncosmo.TimeSeriesSource that adds the ability to return the
#     123     flux density at a given time and wavelength, and changes
#    (...)
#     129     :param kwargs: additional arguments
#     130     """
# --> 131     super(RedbackTimeSeriesSource, self).__init__(phase=phase, wave=wave, flux=flux, **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/sncosmo/models.py:530, in TimeSeriesSource.__init__(self, phase, wave, flux, zero_before, time_spline_degree, name, version)
#     528 self._wave = wave
#     529 self._parameters = np.array([1.])
# --> 530 self._model_flux = Spline2d(phase, wave, flux, kx=time_spline_degree,
#     531                             ky=3)
#     532 self._zero_before = zero_before
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/scipy/interpolate/_fitpack2.py:1590, in RectBivariateSpline.__init__(self, x, y, z, bbox, kx, ky, s)
#    1588     raise ValueError('y must be strictly increasing')
#    1589 if not x.size == z.shape[0]:
# -> 1590     raise ValueError('x dimension of z must have same number of '
#    1591                      'elements as x')
#    1592 if not y.size == z.shape[1]:
#    1593     raise ValueError('y dimension of z must have same number of '
#    1594                      'elements as y')
#
# ValueError: x dimension of z must have same number of elements as x

# %%
#trial for event 2: use the most well known result : GRB 190829A

# 1. The actual data for 190829A - not the same band ! cant find r-band data 
epoch =  12.35
z_event = 0.0785
m_obs_190829A = 21.2  # The r-band apparent magnitude you provided

# 2. Get the 1998bw "Standard" magnitude at THIS epoch and THIS redshift
# We use amplitude=1.0 to get the 'baseline'
m_98bw_baseline = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='magnitude', 
    bands='sdssr' # Match the r-band of your observation
)

# 3. Calculate Ratio
# mag_diff = Observed - Reference
mag_diff = m_obs_190829A - m_98bw_baseline
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days (r-band):")
print(f"SN 1998bw Model Magnitude: {m_98bw_baseline:.2f}")
print(f"GRB 190829A Observed Magnitude: {m_obs_190829A:.2f}")
print(f"Flux Ratio: {flux_ratio:.4f}")

#WELL THIS IS CLEARLY WRONG !!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 10
#       6 m_obs_190829A = 21.2  # The r-band apparent magnitude you provided
#       8 # 2. Get the 1998bw "Standard" magnitude at THIS epoch and THIS redshift
#       9 # We use amplitude=1.0 to get the 'baseline'
# ---> 10 m_98bw_baseline = sn1998bw_template(
#      11     time=epoch,
#      12     redshift=z_event,
#      13     amplitude=1.0,
#      14     output_format='magnitude',
#      15     bands='sdssr' # Match the r-band of your observation
#      16 )
#      18 # 3. Calculate Ratio
#      19 # mag_diff = Observed - Reference
#      20 mag_diff = m_obs_190829A - m_98bw_baseline
#
# Cell In[6], line 86, in sn1998bw_template(time, redshift, amplitude, **kwargs)
#      82     return namedtuple('output', ['time', 'lambdas', 'spectra'])(time=time_obs,
#      83                                                                 lambdas=lambda_obs,
#      84                                                                 spectra=f_lambda_obs)
#      85 else:
# ---> 86     return sed.get_correct_output_format_from_spectra(time=time, time_eval=time_obs,
#      87                                                       spectra=f_lambda_obs, lambda_array=lambda_obs,
#      88                                                       **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:689, in get_correct_output_format_from_spectra(time, time_eval, spectra, lambda_array, **kwargs)
#     687 spectra[spectra.value == 0.] = 1e-30 * np.mean(spectra[5])
#     688 time_spline_degree = kwargs.get('time_spline_degree', 3)
# --> 689 source = RedbackTimeSeriesSource(phase=time_eval, wave=lambda_array, flux=spectra,
#     690                                  time_spline_degree=time_spline_degree)
#     691 if kwargs['output_format'] == 'flux':
#     692     bands = kwargs['bands']
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/redback/sed.py:131, in RedbackTimeSeriesSource.__init__(self, phase, wave, flux, **kwargs)
#     120 def __init__(self, phase, wave, flux, **kwargs):
#     121     """
#     122     RedbackTimeSeriesSource is a subclass of sncosmo.TimeSeriesSource that adds the ability to return the
#     123     flux density at a given time and wavelength, and changes
#    (...)
#     129     :param kwargs: additional arguments
#     130     """
# --> 131     super(RedbackTimeSeriesSource, self).__init__(phase=phase, wave=wave, flux=flux, **kwargs)
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/sncosmo/models.py:530, in TimeSeriesSource.__init__(self, phase, wave, flux, zero_before, time_spline_degree, name, version)
#     528 self._wave = wave
#     529 self._parameters = np.array([1.])
# --> 530 self._model_flux = Spline2d(phase, wave, flux, kx=time_spline_degree,
#     531                             ky=3)
#     532 self._zero_before = zero_before
#
# File /opt/miniconda3/envs/redback/lib/python3.12/site-packages/scipy/interpolate/_fitpack2.py:1590, in RectBivariateSpline.__init__(self, x, y, z, bbox, kx, ky, s)
#    1588     raise ValueError('y must be strictly increasing')
#    1589 if not x.size == z.shape[0]:
# -> 1590     raise ValueError('x dimension of z must have same number of '
#    1591                      'elements as x')
#    1592 if not y.size == z.shape[1]:
#    1593     raise ValueError('y dimension of z must have same number of '
#    1594                      'elements as y')
#
# ValueError: x dimension of z must have same number of elements as x

# %%
#try one more: 
#ensure bands match up !! at least u,g,r,i,z 

# 1. The actual data for 190829A - not the same band ! cant find r-band data 
epoch =  12.35
z_event = 0.0785
m_obs_190829A = 21.2  # The r-band apparent magnitude you provided

# 2. Get the 1998bw "Standard" magnitude at THIS epoch and THIS redshift
# We use amplitude=1.0 to get the 'baseline'
m_98bw_baseline = sn1998bw_template(
    time=epoch, 
    redshift=z_event, 
    amplitude=1.0, 
    output_format='magnitude', 
    bands='sdssr' # Match the r-band of your observation
)

# 3. Calculate Ratio
# mag_diff = Observed - Reference
mag_diff = m_obs_190829A - m_98bw_baseline
flux_ratio = 10**(-0.4 * mag_diff)

print(f"At {epoch} days (r-band):")
print(f"SN 1998bw Model Magnitude: {m_98bw_baseline:.2f}")
print(f"GRB 190829A Observed Magnitude: {m_obs_190829A:.2f}")
print(f"Flux Ratio: {flux_ratio:.4f}")

#test + send emails tomoror

# %%
#work out why this code is breaking - in the meantime create a new jupyter notebook where i can get started on new/other work more upto date 
#figure out this issue of why from redback.transient_models.supernova_models import sn1998bw_template is not loading in 

#direct vs interpolated approaches vary - which is better - hard one to tell !! 
#try to get the direct method working as it was once upon a time 
#is doing import sn_1998bw template possible ? see redback documentation -- 
#speak to gavin tomorrow - have i done the k-correction and the Av correctly - hard to find in papers - direct method vs interpolation
